# %% [markdown]
# #  **EDA on SuperStore Dataset Using Python**

# %%
#importing all liabraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #   *`Data Exploration:`*

# %% [markdown]
# *   **Load the dataset into your preferred data analysis tool (e.g., Python with
# Pandas, Jupyter Notebook, Tableau, etc.)**

# %%
#import superstore dataset

df = pd.read_csv('/content/SampleSuperstore.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## **`READING THE DATA`**
#
#
#
#
#
# ---

# %%
# Display the first 5 rows of the DataFrame

df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Display the last 5 rows of the DataFrame

df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# Access rows 76 to 80 using df.loc[]

df.loc[76:80]
# Out:
#        Ship Mode    Segment        Country     City    State  Postal Code  \
# 76   First Class  Corporate  United States  Houston    Texas        77041
# 77   First Class  Corporate  United States  Houston    Texas        77041
# 78  Second Class   Consumer  United States  Houston    Texas        77070
# 79   First Class  Corporate  United States  Decatur  Alabama        35601
# 80   First Class  Corporate  United States  Decatur  Alabama        35601
#
#      Region         Category Sub-Category    Sales  Quantity  Discount  \
# 76  Central        Furniture  Furnishings    9.708         3       0.6
# 77  Central  Office Supplies      Storage   27.240         3       0.2
# 78  Central        Furniture  Furnishings   19.300         5       0.6
# 79    South  Office Supplies   Appliances  208.160         1       0.0
# 80    South  Office Supplies      Binders   16.740         3       0.0
#
#      Profit
# 76  -5.8248
# 77   2.7240
# 78 -14.4750
# 79  56.2032
# 80   8.0352

# %% [markdown]
# *   **Explore the structure of the dataset, check for missing values, and understand
# the types of data available.**

# %%
# the number of rows and the number of columns

df.shape
# Out:
# (9994, 13)

# %%
# all the columns in the Dataframe

df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# Understand the types of data available

df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# a summary of the data frame

df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# get info about the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# To check if there are null values or missing values

df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# **There are no null values over the entire data.**

# %%
# the unique categories in the data frame.

print(df['Category'].unique())
# Out:
# ['Furniture' 'Office Supplies' 'Technology']

# %%
# the states in the dataset

print(df['State'].unique())
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
# group the data by CATEGORY & SUB-CATEGORY wise

df.groupby(['Category', 'Sub-Category']).sum()
# Out:
#                                                                       Ship Mode  \
# Category        Sub-Category
# Furniture       Bookcases     Second ClassStandard ClassStandard ClassFirst ...
#                 Chairs        Second ClassSecond ClassStandard ClassStandard...
#                 Furnishings   Standard ClassStandard ClassFirst ClassStandar...
#                 Tables        Standard ClassStandard ClassStandard ClassStan...
# Office Supplies Appliances    Standard ClassStandard ClassStandard ClassFirs...
#                 Art           Standard ClassSecond ClassStandard ClassStanda...
#                 Binders       Standard ClassStandard ClassStandard ClassSeco...
#                 Envelopes     Standard ClassStandard ClassStandard ClassSeco...
#                 Fasteners     Standard ClassSecond ClassFirst ClassStandard ...
#                 Labels        Second ClassStandard ClassStandard ClassStanda...
# ...

# %% [markdown]
# # *`Data Cleaning:`*

# %% [markdown]
# *   **Handle missing values, duplicates, and any inconsistencies in the data.**

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# Identify missing values

df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Handle missing values by removing rows with missing values
df_cleaned_missing = df.dropna()


print(df_cleaned_missing)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Identify duplicate rows

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
# Remove duplicate rows

df_cleaned_duplicate = df.drop_duplicates()

print(df_cleaned_duplicate)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Check unique values in 'Ship Mode'

print(df['Ship Mode'].unique())

# Standardize values (e.g., capitalize)

df['Ship Mode'] = df['Ship Mode'].str.capitalize()
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %%
# Check unique values in 'Segment'

print(df['Segment'].unique())

# Standardize values (e.g., capitalize)

df['Segment'] = df['Segment'].str.capitalize()
# Out:
# ['Consumer' 'Corporate' 'Home Office']

# %%
# Check unique values in 'Country'

print(df['Country'].unique())
# Out:
# ['United States']

# %%
# Check unique values in 'City', 'State', 'Postal Code', and 'Region'

print(df['City'].unique())
print(df['State'].unique())
print(df['Postal Code'].unique())
print(df['Region'].unique())

# Standardize values (e.g., capitalize)

df['City'] = df['City'].str.title()
df['State'] = df['State'].str.upper()
# Out:
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
#  'Morristown' 'Cincinnati' 'Inglewood' 'Tamarac' 'Colorado Springs'
# ...

# %%
# Check unique values in 'Category' and 'Sub-Category'

print(df['Category'].unique())
print(df['Sub-Category'].unique())

# Standardize values (e.g., capitalize)

df['Category'] = df['Category'].str.capitalize()
df['Sub-Category'] = df['Sub-Category'].str.capitalize()
# Out:
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
#number of products in each category

df['Category'].value_counts()
# Out:
# Category
# Office supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
#number of Sub-categories products are divided.

df['Sub-Category'].nunique()
# Out:
# 17

# %%
#number of products in each sub-category

df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# *   **Convert data types if necessary.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# **Incorrect Columns Data Type , so changing Data Types**

# %%
# Let's try to change the datatypes of the following column in the dataset.

df['Postal Code'] = df['Postal Code'].astype('object')
df['Quantity'] = df['Quantity'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   object
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 1015.1+ KB

# %% [markdown]
# # *`Descriptive Statistics:`*

# %% [markdown]
# *   **Calculate basic descriptive statistics for key metrics such as total sales,
# average order value, etc.**

# %%
# Calculate basic descriptive statistics

total_sales = df['Sales'].sum()

print(total_sales)
# Out:
# 2297200.8603000003

# %%
avg_order_value = df['Sales'].mean()

print(avg_order_value)
# Out:
# 229.85800083049833

# %%
total_quantity = df['Quantity'].sum()

print(total_quantity)
# Out:
# 37873.0

# %%
total_discount = df['Discount'].sum()

print(total_discount)
# Out:
# 1561.09

# %%
total_profit = df['Profit'].sum()

print(total_profit)
# Out:
# 286397.0217

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# * **Visualize the distribution of sales, order quantity, and other relevant metrics.**

# %%
# Visualize the distribution of sales

plt.figure(figsize=(10, 6))
plt.hist(df['Sales'], bins=50, edgecolor='black', color='black')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')
plt.axvline(x=avg_order_value, color='red', linestyle='dashed', label='Average Order Value')
plt.legend()
plt.show()




# Visualize the distribution of order quantity

plt.figure(figsize=(10, 6))
plt.hist(df['Quantity'], bins=50, edgecolor='black',  color='skyblue')
plt.xlabel('Order Quantity')
plt.ylabel('Frequency')
plt.title('Distribution of Order Quantity')
plt.show()




# Visualize the distribution of profit

plt.figure(figsize=(10, 6))
plt.hist(df['Profit'], bins=50, edgecolor='black', color='green')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.title('Distribution of Profit')
plt.show()




# Visualize the distribution of discount
plt.figure(figsize=(10, 6))
plt.hist(df['Discount'], bins=50, edgecolor='black', color='red')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.title('Distribution of Discount')
plt.show()

# %% [markdown]
# # *`Customer Segmentation:`*

# %% [markdown]
# *   **Segment customers based on their purchasing behavior (e.g., high-value
# customers, frequent customers)**

# %%
# Convert 'Sales' column to numeric if it's not already

df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

# Calculate total sales for each customer

total_sales_per_customer = df.groupby('Segment')['Sales'].sum()

# Calculate number of orders for each customer

order_count_per_customer = df.groupby('Segment').size()

# Calculate average order value for each customer

average_order_value_per_customer = df.groupby('Segment')['Sales'].mean()

# %%
# Segment customers based on purchasing behavior

segmented_customers = pd.DataFrame({
    'Total Sales': total_sales_per_customer,
    'Number of Orders': order_count_per_customer,
    'Average Order Value': average_order_value_per_customer
})

# Print the segmented customers
print(segmented_customers)
# Out:
#               Total Sales  Number of Orders  Average Order Value
# Segment
# Consumer     1.161401e+06              5191           223.733644
# Corporate    7.061464e+05              3020           233.823300
# Home office  4.296531e+05              1783           240.972041

# %% [markdown]
# *   **Analyze the characteristics of each customer segment.**

# %%
# Convert 'Sales' column to numeric if it's not already
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

# Calculate total sales for each customer segment
total_sales_per_segment = df.groupby('Segment')['Sales'].sum()

# Calculate total profit for each customer segment
total_profit_per_segment = df.groupby('Segment')['Profit'].sum()

# Calculate average discount for each customer segment
average_discount_per_segment = df.groupby('Segment')['Discount'].mean()

# Calculate average quantity sold for each customer segment
average_quantity_per_segment = df.groupby('Segment')['Quantity'].mean()

# %%
# Analyze characteristics of each customer segment

segment_characteristics = pd.DataFrame({
    'Total Sales': total_sales_per_segment,
    'Total Profit': total_profit_per_segment,
    'Average Discount': average_discount_per_segment,
    'Average Quantity': average_quantity_per_segment
})

print("Characteristics of Each Customer Segment:")
print(segment_characteristics)
# Out:
# Characteristics of Each Customer Segment:
#               Total Sales  Total Profit  Average Discount  Average Quantity
# Segment
# Consumer     1.161401e+06   134119.2092          0.158141          3.760547
# Corporate    7.061464e+05    91979.1340          0.158228          3.843709
# Home office  4.296531e+05    60298.6785          0.147128          3.782389

# %% [markdown]
# # *`Product Analysis:`*

# %% [markdown]
# *   **Identify the top-selling products and categories.**

# %%
# Convert 'Sales' column to numeric if it's not already

df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

# Calculate total sales for each product

total_sales_per_product = df.groupby('Sub-Category')['Sales'].sum()

# Identify top-selling products

top_selling_products = total_sales_per_product.sort_values(ascending=False).head(10)

# Print the top-selling products

print("Top Selling Products:")
print(top_selling_products)
# Out:
# Top Selling Products:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Name: Sales, dtype: float64

# %%
# Convert 'Sales' column to numeric if it's not already

df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

# Calculate total sales for each category

total_sales_per_category = df.groupby('Category')['Sales'].sum()

# Identify top-selling categories

top_selling_categories = total_sales_per_category.sort_values(ascending=False)

# Print the top-selling categories

print("\nTop Selling Categories:")
print(top_selling_categories)
# Out:
# Top Selling Categories:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office supplies    719047.0320
# Name: Sales, dtype: float64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# *   **Analyze the performance of products over time.**

# %%
# Assuming 'Sales' and 'Profit' columns are available in the dataset as there is no date column in data
# Aggregate data by product category and calculate total sales and profit
product_performance = df.groupby('Category').agg({'Sales': 'sum', 'Profit': 'sum'}).reset_index()

# Sort the data by total sales in descending order
product_performance = product_performance.sort_values(by='Sales', ascending=False)

# Print the top performing products based on total sales and profit
print(product_performance)

# Visualize the data using a bar chart
import matplotlib.pyplot as plt

product_performance.plot(x='Category', y=['Sales', 'Profit'], kind='bar')
plt.title('Product Performance by Sales and Profit')
plt.xlabel('Product Category')
plt.ylabel('Amount')
plt.show()
# Out:
#           Category        Sales       Profit
# 2       Technology  836154.0330  145454.9481
# 0        Furniture  741999.7953   18451.2728
# 1  Office supplies  719047.0320  122490.8008

# %% [markdown]
# # *`Time Series Analysis:`*

# %% [markdown]
# *   **"The dataset 'Superstore Sales' does not include a date column, which means that time series analysis is not possible."**
#
#
# *   **"It was also impossible to proceed with tasks such as examining sales trends over different time periods (e.g., daily, monthly, yearly) and identifying any seasonality or patterns in the sales data."**

# %% [markdown]
# # *`Visualization:`*

# %% [markdown]
# *   **Create visualizations (charts, graphs, dashboards) to present key findings
# effectively.**

# %%
# Showing sales by sub-category

plt.rcParams['figure.figsize'] = (15, 3)
plt.bar(df['Sub-Category'], df['Sales'], color=['blue', 'green', 'red', 'purple', 'orange'])
plt.rcParams.update({'font.size': 10})
plt.xlabel('Sub_Category')
plt.ylabel('Sales')
plt.show()

# %%
# Distribution of sales by category

plt.figure(figsize=(10, 6))
sns.barplot(x="Category", y="Sales", data=df, color="red")
plt.title("Distribution of Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %%
# Profit distribution by region

plt.figure(figsize=(10, 6))
sns.boxplot(x="Region", y="Profit", data=df)
plt.title("Profit Distribution by Region")
plt.xlabel("Region")
plt.ylabel("Profit")
plt.show()

# %%
# Histogram of Sales

plt.figure(figsize=(10, 6))
sns.histplot(df['Sales'], bins=20, kde=True)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar chart of Ship Mode counts

plt.figure(figsize=(8, 5))
sns.countplot(x='Ship Mode', data=df, color="black")
plt.title('Count of Ship Modes')
plt.xlabel('Ship Mode')
plt.ylabel('Count')
plt.show()

# %%
# Boxplot of Sales by Region

plt.figure(figsize=(12, 8))
sns.boxplot(x='Region', y='Sales', data=df)
plt.title('Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()

# %%
# Scatter plot of Sales vs Segment

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sales', y='Segment', data=df, hue='Category')
plt.title('Sales vs Segment')
plt.xlabel('Sales')
plt.ylabel('Segment')
plt.show()

# %%
# Violin plot of Sales distribution by Category

plt.figure(figsize=(12, 8))
sns.violinplot(x='Category', y='Sales', data=df)
plt.title('Sales Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Count plot of Sub-Category

colors = sns.color_palette('pastel')

plt.figure(figsize=(12, 8))
sns.countplot(x='Sub-Category', data=df, order=df['Sub-Category'].value_counts().index, palette=colors)
plt.title('Count of Sub-Categories')
plt.xlabel('Sub-Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-57-d74b65d36885>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sub-Category', data=df, order=df['Sub-Category'].value_counts().index, palette=colors)
# <ipython-input-57-d74b65d36885>:6: UserWarning:
# The palette list has fewer values (10) than needed (17) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='Sub-Category', data=df, order=df['Sub-Category'].value_counts().index, palette=colors)

# %%
# pie chart to visualize the distribution of categories

plt.figure(figsize=(10, 6))

segment = df['Category'].value_counts().index
count = df['Category'].value_counts().values

plt.pie(count, labels=segment, autopct='%1.2f%%', colors=['#ff9999', '#66b3ff', '#99ff99'])

plt.show()

# %%
# KDE plot showing the distribution of sales values

sns.set()
sns.displot(df, x="Sales", kind="kde", multiple="stack",color='green')
plt.show()

# %%
# Exclude non-numeric columns before calculating correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()

# Plot correlation heatmap
sns.heatmap(correlation_matrix, cmap='Reds', annot=True)
plt.rcParams['figure.figsize'] = (10, 5)
plt.show()

# %%
# Define the columns you want to include in the pair plot
columns = ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
           'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit']

# Create the pair plot using the specified columns
sns.pairplot(df[columns], hue='Region', palette='Set1')

plt.show()

# %% [markdown]
# # *`Conclusion and Recommendations:`*

# %% [markdown]
# * **Summarize the main insights derived from the analysis.**

# %% [markdown]
# 1. **Data Exploration:**
#             a. The dataset contains information about sales transactions across
#                different regions, countries, and cities.
#             b. Various attributes such as ship mode, segment, category, and
#                sub-category provide insights into customer behavior and purchasing patterns.
#             c. Exploring the distribution of sales, quantity, discount, and
#                profit helps understand the overall performance of the superstore.
#
#
#
# 2. **Data Cleaning:**
#             a. Handling missing values, duplicates, and inconsistencies ensures
#                the integrity of the dataset for further analysis.
#             b. Standardizing data formats and removing irrelevant columns
#                streamline the data preparation process.
#
#
#
# 3. **Descriptive Statistics:**
#             a. Calculating descriptive statistics provides insights into the
#                central tendencies, variability, and distribution of numerical variables.
#             b. Understanding the range and variability of sales, quantity,
#                discount, and profit helps identify outliers and trends in the data.

# %% [markdown]
# 4. **Customer Segmentation:**
#             a. Segmenting customers based on attributes such as segment,
#                region, or category allows for targeted marketing strategies and personalized customer experiences.
#             b. Analyzing customer segments based on purchasing behavior and
#                profitability helps identify high-value customers and areas for growth.
#
#
#
# 5. **Product Analysis:**
#             a. Analyzing product categories and sub-categories reveals popular
#                products, sales trends, and potential opportunities for product diversification or optimization.
#             b. Understanding the profitability of different products guides
#                inventory management and pricing decisions.
#
#
#
#
# 6. **Visualization:**
#              a. Visualizations such as scatter plots, bar charts, and heatmaps
#                 provide intuitive insights into complex datasets.
#              b. Visualizing sales trends, customer segments, and product
#                 performance facilitates communication of key findings and actionable insights to stakeholders.

# %% [markdown]
# **Overall, the analysis provides valuable insights into the sales performance, customer behavior, and product dynamics of the superstore. These insights can inform strategic decision-making, marketing initiatives, and operational improvements to drive business growth and enhance customer satisfaction.**

# %% [markdown]
# *   **Provide actionable recommendations for improving sales or addressing
# identified challenges.**

# %% [markdown]
# 1. **The main reason which leads to loss is Discount as if some areas lead to loss due to more discounts, and some areas lead to fewer sales due to fewer discounts, hence it needs to be improved.**
#
# 2. **It is better to give more discounts during festival seasons, additionally, that will result in more sales.**
#
# 3. **The Home office segment needs better improvement.**
#
# 4. **Some cities have fewer sales, lack of awareness can be the reason for this, hence advertising in those cities might help in more sales.**
#
# 5. **Identify underperforming product categories or sub-categories and explore opportunities for diversification or expansion into new product lines. Introduce new products that align with customer preferences and market trends to attract new customers and increase sales.**
#
# 6. **Identify new geographic markets or customer segments with growth potential. Develop targeted expansion strategies to penetrate new markets and acquire new customers effectively.**
#
# 7. **Continuously monitor sales performance, customer behavior, and market trends using analytics tools. Leverage data insights to make informed decisions, identify opportunities for improvement, and adjust strategies accordingly to stay competitive in the market.**
#
# 8. **Analyze discounting strategies and their impact on sales and profitability. Implement dynamic pricing models that consider factors such as demand, seasonality, and competitor pricing to optimize pricing strategies and maximize revenue.**

# %% [markdown]
# # *`Documentation:`*

# %% [markdown]
# * **Document your analysis process, including the tools and libraries used.**

# %% [markdown]
# 1. **Data Exploration:**
#           a. Tools Used: Python, Google Colab Notebook
#           b. Libraries Used: pandas, numpy, matplotlib, seaborn
#       *`Process:`*
#              Loaded the dataset using pandas read_csv() function.
#              Explored the dataset structure, dimensions, and data types using info() and head() functions.
#              Analyzed the distribution and summary statistics of numerical variables using describe() function.
#
#
#
# 2. **Data Cleaning:**
#           a. Tools Used: Python, Google Colab Notebook
#           b. Libraries Used: pandas, numpy, matplotlib, seaborn
#       *`Process:`*
#              Handled missing values using dropna() or fillna() functions.
#              Removed duplicate rows using drop_duplicates() function.
#              Standardized data formats and corrected inconsistencies in data using string manipulation functions.
#              Checked for outliers and anomalies in the data and addressed them as needed.

# %% [markdown]
# 3. **Descriptive Statistics:**
#           a. Tools Used: Python, Google Colab Notebook
#           b. Libraries Used: pandas, numpy, matplotlib, seaborn
#       *`Process:`*
#              Calculated descriptive statistics (mean, median, standard
#              deviation, min, max) for numerical variables using describefunction.
#              Visualized the distribution of numerical variables using
#              histograms, box plots, or density plots using matplotlib and seaborn.
#
#
#
#
# 4. **Customer Segmentation:**
#
#           a. Tools Used: Python, Google Colab Notebook
#           b. Libraries Used: pandas, numpy, matplotlib, seaborn
#       *`Process:`*
#              Segmented customers based on attributes such as segment, region,   `or category.
#              Analyzed customer segments based on purchasing behavior, profitability, and other relevant factors.

# %% [markdown]
# 5. **Product Analysis:**
#           a. Tools Used: Python, Google Colab Notebook
#           b. Libraries Used: pandas, numpy, matplotlib, seaborn
#       *`Process:`*
#              Analyzed product categories and sub-categories to identify popular products, sales trends, and profitability.
#              Explored opportunities for product diversification or optimization based on sales performance.
#
#
#
#
# 6. **Visualization:**
#
#           a. Tools Used: Python, Google Colab Notebook
#           b. Libraries Used: pandas, numpy, matplotlib, seaborn
#       *`Process:`*
#             Created visualizations such as scatter plots, bar charts, heatmaps,
#             and pair plots to communicate key insights effectively.
#             Customized visualizations to enhance readability and clarity using  matplotlib and seaborn.

# %% [markdown]
# **This documentation outlines the analysis process, tools, and libraries used to analyze the "superstore_sales" dataset, derive insights, and provide actionable recommendations for improving sales performance.**

# %% [markdown]
# * **Share your findings in a report or presentation format.**

# %% [markdown]
# **Slide 1: Title Slide**
#
#               * `Title:`              Superstore Sales Analysis
#               * `Subtitle:`           Insights and Recommendations for Improvement
#
#
# **Slide 2: Introduction**
#
#               * Overview of the analysis objectives and scope.
#               *  Importance of analyzing sales data for business growth and strategy development.
#
#
# **Slide 3: Dataset Overview**
#
#               * `Brief description of the dataset:` "Superstore sales".
#               * List of columns included in the dataset.
#
#
# **Slide 4: Analysis Process**
#
#               * Overview of the analysis process:
#               * Data Exploration
#               * Data Cleaning
#               * Descriptive Statistics
#               * Customer Segmentation
#               * Product Analysis
#               * Visualization
#               * Actionable Recommendations
#
#
# **Slide 5: Data Exploration**
#
#               * Summary of key findings from data exploration:
#                   a. Distribution of sales transactions across regions,
#                      countries, and cities.
#                   b. Insights from various attributes such as ship mode,
#                      segment, category, and sub-category.
#
#
# **Slide 6: Data Cleaning**
#
#               * Overview of data cleaning process:
#               * Handling missing values, duplicates, and inconsistencies.
#               * Standardizing data formats and removing irrelevant columns.
#
#
# **Slide 7: Descriptive Statistics**
#
#               * Summary of descriptive statistics:
#                   * Central tendencies, variability, and distribution of sales,
#                     quantity, discount, and profit.
#                   * Identification of outliers and trends in the data.
#
#
# **Slide 8: Customer Segmentation**
#
#               * Insights from customer segmentation analysis:
#                   * Segmentation based on attributes such as segment, region, or category.
#                   * Identification of high-value customer segments for targeted marketing strategies.
#
#
# **Slide 9: Product Analysis**
#
#               * Key findings from product analysis:
#                    * Analysis of product categories and sub-categories.
#                    * Identification of popular products, sales trends, and profitability.
#
#
# **Slide 10: Visualization**
#
#               * Visual presentation of key insights:
#                    * Scatter plots, bar charts, heatmaps, and pair plots.
#                    * Communication of insights through visualizations for better understanding.

# %% [markdown]
# **Slide 11: Actionable Recommendations**
#
#               * Actionable recommendations for improving sales performance:
#               * Targeted marketing campaigns
#               * Product diversification
#               * Price optimization
#               * Inventory management
#               * vCustomer experience enhancement
#               * Market expansion
#               * Data-driven decision making
#               * Cross-selling and upselling
#               * Customer retention
#               * Employee training and development
#
#
# **Slide 12: Conclusion**
#
#               * Summary of key findings and recommendations.
#               * Importance of implementing recommendations for business growth
#                 and success.
#
#
# **Slide 13: Q&A**
#
#               * Opportunity for audience questions and discussion.
#
#
# **Slide 14: Thank You**
#
#               * Thanking the audience for their attention and participation.
#
#
#
#
# **This presentation provides a comprehensive overview of the analysis process, key findings, and actionable recommendations derived from the Superstore sales dataset analysis. It aims to inform stakeholders and decision-makers about strategies for improving sales performance and addressing business challenges effectively.**
